# %%
import pandas as pd
from pypdf import PdfReader
import re
from datetime import datetime
import os

# %%
date_pattern_year = r'^\d{2}/\d{2}/\d{4}'
date_pattern = r'^\d{2}/\d{2}'
mistaken_pattern = r'(\d+/\d+)\s*([\d,.]+)'
mistaken_pattern1 = r'^([a-zA-Z]+)\\S([0-9]+\\,[0-9]+)',
fraction_pattern = r'(\d/\d)'
banrisul_pattern = r'\+\+\s*MOVIMENTOS\s+(\w+)\/(\d{4})'
banrisul_pattern_2 = r'^(\d*)\s+(\D+)\s+\d+\s+(\d+\,\d+)(\-*)'

# %%
def extract_data(file_path,passwd=None):
    reader = PdfReader(file_path)
    if reader.is_encrypted:
        reader.decrypt(passwd)
    return [page.extract_text().splitlines() for page in reader.pages]

# %%
def extract_info(file_path,passwd=None):
    pdf_data = extract_data(file_path,passwd)
    # Combine patterns into a single pattern using alternation
    combined_pattern = re.compile(f"({date_pattern})|({date_pattern_year})|({mistaken_pattern})")
    # Use list comprehension to filter lines that match any of the combined patterns
    return [line for data in pdf_data for line in data if combined_pattern.match(line)]

# %%
def convert_brazil_to_us_currency(brazil_currency):
    # Remove any dots used as thousand separators
    brazil_currency_no_thousand_sep = brazil_currency.replace('.', '')
    # Replace the comma used as a decimal separator with a dot
    us_currency = brazil_currency_no_thousand_sep.replace(',', '.')
    return us_currency

# %%
def get_month_number_abbr(month_name_abbr):
    # Define a mapping of month abbreviations to month numbers
    month_abbr_to_number = {
        'jan': 1, 'fev': 2, 'mar': 3, 'abr': 4,
        'mai': 5, 'jun': 6, 'jul': 7, 'ago': 8,
        'set': 9, 'out': 10, 'nov': 11, 'dez': 12
    }
    
    # Convert the abbreviation to lowercase to handle case-insensitivity
    month_name_abbr_lower = month_name_abbr.lower()
    
    # Lookup the month number based on the abbreviation
    month_number = month_abbr_to_number.get(month_name_abbr_lower)
    
    return month_number

# %%
def extract_charges(text):
    # Split the text into lines
    lines = text.split('\n')
    
    # Initialize variables
    charges = []
    current_cardholder = None
    
    # Pattern to match cardholder names
    cardholder_pattern = re.compile(r'^\*\*(.+?)\*\*$')
    
    # Pattern to match charges
    charge_pattern = re.compile(r'^\*(\d{2}/\d{2})\s(.+?)\s-\sR\$\s([\d,]+(\(\d+/\d+\))?)\*')
    
    for line in lines:
        # Check for cardholder name
        cardholder_match = cardholder_pattern.match(line.strip())
        if cardholder_match:
            current_cardholder = cardholder_match.group(1)
            continue
        
        # Check for charges
        charge_match = charge_pattern.match(line.strip())
        if charge_match:
            date, description, amount = charge_match.groups()[:3]
            charges.append({
                'cardholder': current_cardholder,
                'date': date,
                'description': description,
                'amount': amount
            })
    
    return charges

def create_dataframe(charges):
    # Create a DataFrame from the list of charges
    df = pd.DataFrame(charges)
    return df

# %%
file_path = ['/home/jpchagas/Downloads/guaiaca_dash/bradesco/bradesco_fatura_janeiro.pdf',
            '/home/jpchagas/Downloads/guaiaca_dash/bradesco/bradesco_fatura_fevereiro.pdf',
            '/home/jpchagas/Downloads/guaiaca_dash/bradesco/bradesco_fatura_marco.pdf',
            '/home/jpchagas/Downloads/guaiaca_dash/bradesco/bradesco_fatura_abril.pdf',
            '/home/jpchagas/Downloads/guaiaca_dash/bradesco/bradesco_fatura_maio.pdf']
consolidated_info = []
for file in file_path:
    charges = extract_data(file,"5593")
    consolidated_info.append(charges)
# Extract and create DataFrame
#charges = extract_charges(bill_text)
#df = create_dataframe(charges)

# Display the DataFrame
#print(df)

# %%
consolidated_info
# Out:
# [[['XXXX.XXXX.XXXX.9787XXXX.XXXX.XXXX.9787',
#    'Aplicativo Bradesco Cartões',
#    'Data: 27/05/2024 - 21:31',
#    'Situação do Extrato: FECHADO',
#    'JOAO PEDRO CHAGAS - VISA INFINITE',
#    'Data HistóricoMoeda de',
#    'origemUS$Cotação',
#    'US$R$',
#    '.Total para JOAO PEDRO',
#    'CHAGAS. .. R$ 0,00',
#    'JOAO PEDRO CHAGAS - VISA INFINITE',
#    'Data HistóricoMoeda de',
#    'origemUS$Cotação',
#    'US$R$',
#    '25/12 POSTOS BAUER IIII 200,38',
#    '24/12 Sem Par*Sem Parar * 97,00',
#    '24/12 FARMACIA XAXIM 30,88',
#    '23/12 POSTO Z4 222,48',
#    '23/12 MIRANTES 36,00',
#    '21/12 EBN *SPOTIFY 34,90',
#    '20/12 FERRAMENTAS GERAIS 17,27',
#    '18/12KALUNGA IGUATEMI PORTO',
#    '1/359,34',
#    '18/12 MULTIFESTA 9,98',
#    '17/12 VELEIROS DO SUL 25,00'],
#   ['17/12 99APP *99App 25,95',
#    '17/12 PG *LEROY MERLIN LEROY 69,90',
#    '16/12 N Y ARTIGO 1/4 62,75',
#    '16/12 PUC CAMPUS FACULDADE 10,00',
#    '16/12 99APP *99App 27,10',
#    '15/12 EC*INSIDERSTORE 1/3 154,67',
#    '15/12 MP *UNICOMPECASPA 18,00',
#    '15/12 CASA ARCO 70,00',
#    '15/12 PAG*Barbershop 30,00',
#    '14/12 PORTO SEGURO CIA SEG G 185,34',
#    '14/12 Uber *UBER *TRIP 20,93',
#    '14/12 99APP *99App 17,90',
#    '11/12 PAGTO. POR DEB EM C/C -8.660,94',
#    '10/12 SALDO ANTERIOR 8.660,94',
#    '09/12 LE BATEAU IVRE 375,65',
#    '09/12 PAG*CasaMaria 139,80',
#    '05/12 SOMPO *Parcela*3-3 92,64',
#    '04/12 99* POP 04Dez 09h58min 8,73',
#    '04/12 99* POP 04Dez 08h57min 8,60',
#    '03/12 99* POP 03Dez 00h45min 32,16',
#    '03/12 Uber *UBER *TRIP 11,70'],
#   ['XXXX.XXXX.XXXX.481102/12 UBER* TRIP 5,00',
#    '02/12 FARM POP UP PRAIA DE B 149,00',
#    '02/12 PONTE CAPITAL LTDA EPP 111,10',
#    '02/12 CASA DO VALE 137,68',
#    '02/12 HAVAIANAS 69,99',
#    '01/12 FUI GOSTEI AGENCIA DE 1.065,67',
#    '01/12 FAREJANDOST 1/2 174,00',
#    '01/12 MP *CASARIOATELIE 72,00',
#    '01/12 ZAFFARI F. MACHAD 75,70',
#    '30/11 AmazonPrimeBR 14,90',
#    '30/10 AMAZON MARKETPLACE 2/4 62,22',
#    '08/10 PG *SPIRITO SANTO 3/6 183,17',
#    '06/09 CNS IG PORTO ALEGRE 4/6 114,83',
#    '.Total para JOAO PEDRO',
#    'CHAGAS. ..R$',
#    '4.330,31',
#    'RAFAELA KOEFENDER - VISA INFINITE',
#    'Data HistóricoMoeda de',
#    'origemUS$Cotação',
#    'US$R$',
#    '23/12 HNA*OBOTICARIO 1/4 78,19',
#    '23/12 SHOPPING DO REAL 54,85',
#    '22/12 AREATECTECNO*Digipare 5,00',
#    '22/12 PAG*FigmigCentroDe 132,50',
#    '21/12 UBER* TRIP 30,43'],
#   ['21/12 COTTON ON DO FILIAL 00 1/2 89,95',
#    '21/12DECATHLON PRAIA DE BEL',
#    '1/274,98',
#    '21/12LOCCITANE PRAIA DE BEL',
#    '1/468,65',
#    '21/12 LOESCH E SCHUCK ADMI 40,00',
#    '20/12 Uber *UBER *TRIP 14,93',
#    '19/12 CASA DO PAPEL 5,78',
#    '18/12 STUDIO FLOE 99,00',
#    '18/12 K2 COMERCIO E INDUSTRI 1/4 67,50',
#    '16/12 J L C ARTIGOS DO VESTU 44,99',
#    '16/12 LOJAS AMERICANAS 42 149,39',
#    '16/12 Uber *UBER *TRIP 20,80',
#    '16/12 BAR ODESSA 39,35',
#    '16/12 TUYO 99,00',
#    '15/12 EC*INSIDERSTORE 1/3 264,68',
#    '14/12 SABOR DE LUNA 6,60',
#    '13/12 PAG*MercadoMoinhos 26,74',
#    '12/12 CEA PAB 310 ECPC 1/3 150,99',
#    '12/12 RAIA 210 131,71',
#    '12/12 LOJAS AMERICANAS 154 36,47',
#    '11/12 PAG*ICASEIPRESENTES 331,57'],
#   ['11/12 NETFLIX.COM 52,80',
#    '11/12 PUBLIC MARKET 21,60',
#    '09/12 PAG*MaxmixComercial 149,96',
#    '08/12 POSTO SHOPPING 246,67',
#    '06/12 AREATECTECNO*Digipare 50,00',
#    '05/12 MERCADO MOINHOS 9,45',
#    '05/12 PANVEL FARMACIAS 25,41',
#    '04/12 369 ARMAZEM CAFE 16,34',
#    '04/12 MP *MELIMAIS 17,99',
#    '03/12 RAIA3286 1/3 65,40',
#    '01/12 APOIASE*APOIAse apadr 15,00',
#    '30/11 ZEREZES DESIGN 1/8 123,75',
#    '30/11 UBER* TRIP 14,91',
#    '30/11 UBER* TRIP 34,40',
#    '30/11 RAIA1504 111,81',
#    '30/11 TAISHI SUSHI 65,89',
#    '30/11 PG *TON CRUA SLOW BE 256,00',
#    '29/11 BACIO LJ 0092 RUA P CH 17,95',
#    '24/11 Azul *FM12VAOliveir 2/6 69,80',
#    '23/11 PAG*Panvelfilial407 2/2 34,78',
#    '21/11 FARMACIA SAO JOAO 2/2 65,68',
#    '01/11 PAG*DanielleLouiseAce 2/2 157,50'],
#   ['01/11 CHEVERE 2/2 79,95',
#    '30/10 PANVEL FARMACIAS 2/2 87,89',
#    '25/10 simple *SimpleOrganic 3/4 62,15',
#    '10/10 PAG*PetzCarlosBerta 3/4 88,48',
#    '12/09JOULI SAUDE EM ESTETICA L',
#    '4/10100,00',
#    '06/09 AMAZON BR 4/10 149,15',
#    '06/09 RENNER 4/4 61,45',
#    '29/08JOULI SAUDE EM ESTETICA L',
#    '4/12170,83',
#    '18/08 AMAZON MARKETPLACE 5/7 52,97',
#    '01/08 RENNER 5/5 95,98',
#    '22/07 Vindi *CasaBoaVistaTe 6/6 54,16',
#    '11/07 AMAZON MARKETPLACE 6/10 68,14',
#    '01/07JOULI SAUDE EM ESTETICA L',
#    '6/12345,83',
#    '31/03JOULI SAUDE EM ESTETICA L',
#    '9/1095,00',
#    '23/02 PARC=112CONQUER 11/12 158,75',
#    '25/01 EBW*CANVA 12/12 24,15',
#    '.Total para RAFAELA',
#    'KOEFENDER. ..R$',
#    '5.382,02',
#    '. Total da Fatura em Real . ..R$',
#    '9.712,33'],
#   []],
#  [['XXXX.XXXX.XXXX.9787XXXX.XXXX.XXXX.9787',
#    'Aplicativo Bradesco Cartões',
#    'Data: 27/05/2024 - 21:31',
#    'Situação do Extrato: FECHADO',
#    'JOAO PEDRO CHAGAS - VISA INFINITE',
#    'Data HistóricoMoeda de',
#    'origemUS$Cotação',
#    'US$R$',
#    '.Total para JOAO PEDRO',
#    'CHAGAS. .. R$ 0,00',
#    'JOAO PEDRO CHAGAS - VISA INFINITE',
#    'Data HistóricoMoeda de',
#    'origemUS$Cotação',
#    'US$R$',
#    '28/01 PAG*RejaneFerreiraDa 114,00',
#    '28/01 PAG*LancheriaAmigosDa 49,10',
#    '27/01 NOSTRO MOLINO RESTAURA 218,57',
#    '27/01 CNO GASTRONOMIA LTDA 167,91',
#    '26/01 DECATHLON PRAIA DE BEL 19,98',
#    '24/01 FARMACIA MARCELA 30,50',
#    '24/01 Sem Par*Sem Parar * 23,20',
#    '23/01 99APP *99App 10,00',
#    '23/01 99* POP 23Jan 09h56min 9,76',
#    '21/01 EBN *SPOTIFY 34,90'],
#   ['XXXX.XXXX.XXXX.481120/01 PET LOVE*Order10054397 146,80',
#    '10/01 SALDO ANTERIOR 9.712,33',
#    '10/01 PAGTO. POR DEB EM C/C -9.712,33',
#    '31/12 AmazonPrimeBR 14,90',
#    '18/12KALUNGA IGUATEMI PORTO',
#    '2/359,33',
#    '16/12 N Y ARTIGO 2/4 62,72',
#    '15/12 EC*INSIDERSTORE 2/3 154,67',
#    '01/12 FAREJANDOST 2/2 174,00',
#    '30/10 AMAZON MARKETPLACE 3/4 62,22',
#    '08/10 PG *SPIRITO SANTO 4/6 183,17',
#    '06/09 CNS IG PORTO ALEGRE 5/6 114,83',
#    '.Total para JOAO PEDRO',
#    'CHAGAS. ..R$',
#    '1.650,56',
#    'RAFAELA KOEFENDER - VISA INFINITE',
#    'Data HistóricoMoeda de',
#    'origemUS$Cotação',
#    'US$R$',
#    '25/01 DINARTE RESTAURANTE L 88,00',
#    '25/01 CASA DO PAPEL 5,38',
#    '22/01 AREATECTECNO*Digipare 50,00',
#    '22/01 AREATECTECNO*Digipare 50,00',
#    '20/01 3434RAIA 24,18',
#    '20/01 ABASTEC*abastece ai 214,57'],
#   ['20/01 PAG*SabineMarianeSaue 28,00',
#    '15/01 HOTEL MONTE CARLO 344,00',
#    '15/01 POSTO PRIMAR 136,01',
#    '15/01 EMPORIO PROSPERATO 49,00',
#    '14/01 BOTECO BEER 127,00',
#    '11/01 NETFLIX.COM 52,80',
#    '03/01 MP *MELIMAIS 17,99',
#    '01/01 APOIASE*APOIAse apadr 15,00',
#    '23/12 HNA*OBOTICARIO 2/4 78,17',
#    '21/12 COTTON ON DO FILIAL 00 2/2 89,95',
#    '21/12DECATHLON PRAIA DE BEL',
#    '2/274,98',
#    '21/12 LOCCITANE PRAIA DE BEL 2/4 68,65',
#    '18/12 K2 COMERCIO E INDUSTRI 2/4 67,50',
#    '15/12 EC*INSIDERSTORE 2/3 264,66',
#    '12/12 CEA PAB 310 ECPC 2/3 150,98',
#    '03/12 RAIA3286 2/3 65,39',
#    '30/11 ZEREZES DESIGN 2/8 123,75',
#    '24/11 Azul *FM12VAOliveir 3/6 69,80',
#    '25/10 simple *SimpleOrganic 4/4 62,15',
#    '10/10 PAG*PetzCarlosBerta 4/4 88,48',
#    '12/09JOULI SAUDE EM ESTETICA L',
#    '5/10100,00'],
#   ['06/09 AMAZON BR 5/10 149,15',
#    '29/08JOULI SAUDE EM ESTETICA L',
#    '5/12170,83',
#    '18/08 AMAZON MARKETPLACE 6/7 52,97',
#    '11/07 AMAZON MARKETPLACE 7/10 68,14',
#    '01/07JOULI SAUDE EM ESTETICA L',
#    '7/12345,83',
#    '31/03JOULI SAUDE EM ESTETICA L',
#    '10/1095,00',
#    '23/02 PARC=112CONQUER 12/12 158,75',
#    '.Total para RAFAELA',
#    'KOEFENDER. ..R$',
#    '3.547,06',
#    '. Total da Fatura em Real . ..R$',
#    '5.197,62']],
#  [['XXXX.XXXX.XXXX.9787XXXX.XXXX.XXXX.9787',
#    'Aplicativo Bradesco Cartões',
#    'Data: 27/05/2024 - 21:31',
#    'Situação do Extrato: FECHADO',
#    'JOAO PEDRO CHAGAS - VISA INFINITE',
#    'Data HistóricoMoeda de',
#    'origemUS$Cotação',
#    'US$R$',
#    '.Total para JOAO PEDRO',
#    'CHAGAS. .. R$ 0,00',
#    'JOAO PEDRO CHAGAS - VISA INFINITE',
#    'Data HistóricoMoeda de',
#    'origemUS$Cotação',
#    'US$R$',
#    '23/02 Sem Par*Sem Parar * 114,60',
#    '18/02 AMAZON MARKETPLACE 36,90',
#    '17/02 PAG*Barbershop 30,00',
#    '17/02 AMAZON MARKETPLACE 81,98',
#    '15/02PORTO SEGURO CIA SEG G',
#    '1/10241,55',
#    '15/02 PAG*Safe 15,00',
#    '14/02 PAGTO. POR DEB EM C/C -5.197,62',
#    '14/02 DECATHLON PRAIA DE BEL 9,98',
#    '13/02 RAIA DROGASIL S A 1/3 26,64',
#    '11/02 SUPER LOJA 15,98'],
#   ['11/02 KARINE DE SOUZA BITTEN 84,00',
#    '10/02 SALDO ANTERIOR 5.197,62',
#    '10/02 NADIA SIMONE SANTOS DE 96,00',
#    '09/02 ABASTEC*abastece ai 210,32',
#    '07/02 BOURBON IPIRANGA 1/3 156,22',
#    '06/02 PAG*OdecioEtter 20,00',
#    '05/02 MAKRO CENTRAL DE AVIAM 14,39',
#    '05/02 99* 6,30',
#    '05/02 Gympass GympassBr 269,90',
#    '04/02MOO VEGGIE FOOD',
#    'RESTAURAN123,70',
#    '04/02 CIA DO ESCONDIDINHO 152,00',
#    '04/02 Gympass GympassBr 129,90',
#    '03/02 PAG*RejaneFerreiraDa 20,00',
#    '03/02 PAG*PointMixChurros 20,00',
#    '02/02 LOJA E BAZAR TODO DIA 1/3 37,97',
#    '02/02 JEFERSON BITTENCOURT C 12,00',
#    '02/02 COMERCIAL UNIAO EIRELI 69,88',
#    '02/02 SUPERBOM SUPERMERCADO 107,88',
#    '31/01 AmazonPrimeBR 14,90',
#    '29/01 PAG*LucasBarreiro 204,00',
#    '18/12KALUNGA IGUATEMI PORTO',
#    '3/359,33'],
#   ['XXXX.XXXX.XXXX.481116/12 N Y ARTIGO 3/4 62,72',
#    '15/12 EC*INSIDERSTORE 3/3 154,67',
#    '30/10 AMAZON MARKETPLACE 4/4 62,22',
#    '08/10 PG *SPIRITO SANTO 5/6 183,17',
#    '06/09 CNS IG PORTO ALEGRE 6/6 114,83',
#    '.Total para JOAO PEDRO',
#    'CHAGAS. ..R$',
#    '2.958,93',
#    'RAFAELA KOEFENDER - VISA INFINITE',
#    'Data HistóricoMoeda de',
#    'origemUS$Cotação',
#    'US$R$',
#    '27/02 CA Modas Ltda. CEA-664424 1/3 497,33',
#    '27/02 BUFFON 43 4,98',
#    '27/02 PANVEL FARMACIAS 79,06',
#    '27/02 BUFFON 43 12,45',
#    '23/02 CONQUER 158,75',
#    '22/02 BACIO LJ 0092 RUA P CH 46,90',
#    '22/02 MERCADO MORARI 28,90',
#    '22/02 AMAZON MARKETPLACE 99,99',
#    '21/02 MERCADO MORARI 7,00',
#    '19/02 SHOULDER E-COMMERCE 459,00',
#    '19/02 PG *FELICITOUS LUCAS40 150,00',
#    '17/02 HOSPITAL MAE DE DEUS G 42,00'],
#   ['16/02 DIGIPARE 50,00',
#    '11/02 NETFLIX ENTRETENIMENTO 52,80',
#    '10/02 PANVEL FARMACIAS 749 36,51',
#    '09/02 PAG*FigmigCentroDe 40,00',
#    '08/02 PDV*SANTINO.ARTISAN 16,00',
#    '06/02 HNA*OBOTICARIO 1/2 86,40',
#    '06/02 AREATECTECNO*Digipare 50,00',
#    '06/02 IGUATEMI 28,00',
#    '06/02 IGUATEMI 39,50',
#    '06/02 PAG*MercadoMoinhos 29,50',
#    '06/02 PAG*PortoAlegreSthShP 44,90',
#    '02/02 MP *MELIMAIS 17,99',
#    '01/02 DROGARIA ONL*Drog 1/2 117,57',
#    '01/02 APOIASE*APOIAse apadr 15,00',
#    '01/02 PAG*FigmigCentroDe 84,00',
#    '01/02 LS FARMACIAS 27,90',
#    '31/01 DROGARIA ONL*Drog 1/2 65,45',
#    '31/01 MERCADO MOINHOS 40,50',
#    '31/01 ZAFFARI C. COLOMB 10,90',
#    '31/01 abastec*abastece ai 245,35',
#    '30/01 SIMPLE POA 1/2 102,45'],
#   ['29/01 PANVEL FARMACIAS 9,99',
#    '29/01 PAG*MercadoMoinhos 8,55',
#    '23/12 HNA*OBOTICARIO 3/4 78,17',
#    '21/12LOCCITANE PRAIA DE BEL',
#    '3/468,65',
#    '18/12 K2 COMERCIO E INDUSTRI 3/4 67,50',
#    '15/12 EC*INSIDERSTORE 3/3 264,66',
#    '12/12 CEA PAB 310 ECPC 3/3 150,98',
#    '03/12 RAIA3286 3/3 65,39',
#    '30/11 ZEREZES DESIGN 3/8 123,75',
#    '24/11 Azul *FM12VAOliveir 4/6 69,80',
#    '12/09JOULI SAUDE EM ESTETICA L',
#    '6/10100,00',
#    '06/09 AMAZON BR 6/10 149,15',
#    '29/08JOULI SAUDE EM ESTETICA L',
#    '6/12170,83',
#    '18/08 AMAZON MARKETPLACE 7/7 52,97',
#    '11/07 AMAZON MARKETPLACE 8/10 68,14',
#    '01/07JOULI SAUDE EM ESTETICA L',
#    '8/12345,83',
#    '.Total para RAFAELA',
#    'KOEFENDER. ..R$',
#    '4.581,44',
#    '. Total da Fatura em Real . ..R$',
#    '7.540,37']],
#  [['XXXX.XXXX.XXXX.9787XXXX.XXXX.XXXX.9787',
#    'Aplicativo Bradesco Cartões',
#    'Data: 27/05/2024 - 21:31',
#    'Situação do Extrato: FECHADO',
#    'JOAO PEDRO CHAGAS - VISA INFINITE',
#    'Data HistóricoMoeda de',
#    'origemUS$Cotação',
#    'US$R$',
#    '.Total para JOAO PEDRO',
#    'CHAGAS. .. R$ 0,00',
#    'JOAO PEDRO CHAGAS - VISA INFINITE',
#    'Data HistóricoMoeda de',
#    'origemUS$Cotação',
#    'US$R$',
#    '23/03 Sem Par*Sem Parar * 17,45',
#    '23/03 PAG*Barbershop 30,00',
#    '23/03 VENEZA PADARIA 12,50',
#    '23/03 LH FRANCO 10,00',
#    '23/03 MERCADO OLIMPICO 15,00',
#    '11/03 PAGTO. POR DEB EM C/C -7.540,37',
#    '10/03 SALDO ANTERIOR 7.540,37',
#    '15/02PORTO SEGURO CIA SEG G',
#    '2/10241,53',
#    '13/02 RAIA DROGASIL S A 2/3 26,63',
#    '07/02 BOURBON IPIRANGA 2/3 156,22'],
#   ['XXXX.XXXX.XXXX.481102/02 LOJA E BAZAR TODO DIA 2/3 37,96',
#    '16/12 N Y ARTIGO 4/4 62,72',
#    '08/10 PG *SPIRITO SANTO 6/6 183,17',
#    '.Total para JOAO PEDRO',
#    'CHAGAS. ..R$',
#    '793,18',
#    'RAFAELA KOEFENDER - VISA INFINITE',
#    'Data HistóricoMoeda de',
#    'origemUS$Cotação',
#    'US$R$',
#    '26/03 Uber *UBER *TRIP 21,36',
#    '26/03 Uber *UBER *TRIP 8,91',
#    '26/03 ARMAZEM 43. 24OUT 24,50',
#    '25/03 ARMAZEM 43. 24OUT 27,77',
#    '22/03 DIGIPARE 50,00',
#    '20/03 369 ARMAZEM CAFE 12,75',
#    '19/03 PAG*PanvelFilial9 59,07',
#    '16/03 REK PARKING EMPREEND E 25,00',
#    '16/03 POSTO PERIMETRAL 186,59',
#    '14/03 pgz*ISAINSTIT 169,00',
#    '14/03 Vindi *Figmigcentrode 109,90',
#    '12/03 APOIASE*APOIAse proje 25,00',
#    '11/03 DIGIPARE 50,00',
#    '09/03 CEA PAC 300 ECPC 1/2 70,61'],
#   ['08/03 UBER* TRIP 8,94',
#    '08/03 DERMO MOINHOS 37,20',
#    '08/03 Uber *UBER *TRIP 9,36',
#    '08/03 INCOMUM 10,00',
#    '07/03 369 ARMAZEM CAFE 3,50',
#    '06/03 210RAIA 96,93',
#    '06/03 PANVEL FARMACIAS 99,48',
#    '06/03 ARMAZEM 43. 24OUT 14,00',
#    '05/03 PG *DROGARAIA DROGARIA 69,01',
#    '03/03 MP *MELIMAIS 17,99',
#    '01/03 APOIASE*APOIAse apadr 15,00',
#    '28/02 RAIA DROGASIL SA 55,90',
#    '06/02 HNA*OBOTICARIO 2/2 86,40',
#    '01/02 DROGARIA ONL*Drog 2/2 117,56',
#    '31/01 DROGARIA ONL*Drog 2/2 65,44',
#    '30/01 SIMPLE POA 2/2 102,45',
#    '23/12 HNA*OBOTICARIO 4/4 78,17',
#    '21/12LOCCITANE PRAIA DE BEL',
#    '4/468,65',
#    '18/12 K2 COMERCIO E INDUSTRI 4/4 67,50',
#    '30/11 ZEREZES DESIGN 4/8 123,75',
#    '24/11 Azul *FM12VAOliveir 5/6 69,80'],
#   ['12/09JOULI SAUDE EM ESTETICA L',
#    '7/10100,00',
#    '06/09 AMAZON BR 7/10 149,15',
#    '29/08JOULI SAUDE EM ESTETICA L',
#    '7/12170,83',
#    '11/07 AMAZON MARKETPLACE 9/10 68,14',
#    '01/07JOULI SAUDE EM ESTETICA L',
#    '9/12345,83',
#    '.Total para RAFAELA',
#    'KOEFENDER. ..R$',
#    '2.891,44',
#    '. Total da Fatura em Real . ..R$',
#    '3.684,62']],
#  [['XXXX.XXXX.XXXX.9787XXXX.XXXX.XXXX.9787',
#    'Aplicativo Bradesco Cartões',
#    'Data: 27/05/2024 - 21:31',
#    'Situação do Extrato: FECHADO',
#    'JOAO PEDRO CHAGAS - VISA INFINITE',
#    'Data HistóricoMoeda de',
#    'origemUS$Cotação',
#    'US$R$',
#    '.Total para JOAO PEDRO',
#    'CHAGAS. .. R$ 0,00',
#    'JOAO PEDRO CHAGAS - VISA INFINITE',
#    'Data HistóricoMoeda de',
#    'origemUS$Cotação',
#    'US$R$',
#    '28/04IFD*OUTBACK STEAKHOUSE',
#    'RE250,39',
#    '23/04 Sem Par*Sem Parar * 67,99',
#    '10/04 SALDO ANTERIOR 3.684,62',
#    '10/04 PAGTO. POR DEB EM C/C -3.684,62',
#    '15/02 PORTO SEGURO CIA SEG G 3/10 241,53',
#    '13/02 RAIA DROGASIL S A 3/3 26,63',
#    '07/02 BOURBON IPIRANGA 3/3 156,22',
#    '02/02 LOJA E BAZAR TODO DIA 3/3 37,96',
#    '.Total para JOAO PEDRO',
#    'CHAGAS. ..R$',
#    '780,72'],
#   ['XXXX.XXXX.XXXX.4811 RAFAELA KOEFENDER - VISA INFINITE',
#    'Data HistóricoMoeda de',
#    'origemUS$Cotação',
#    'US$R$',
#    '27/04 PAG*FigmigCentroDe 47,50',
#    '27/04 PAG*CmCentroDeBeleza 59,00',
#    '23/04 PAG*GamalFouadEl 1/5 105,40',
#    '23/04 UBER* TRIP 11,97',
#    '23/04 PANVEL FARMACIAS 87,89',
#    '23/04 Uber *UBER *TRIP 13,90',
#    '23/04 K & M ARTESANATOS 34,00',
#    '22/04 RESTAURANTE AROMA MINE 63,25',
#    '22/04 UBER* TRIP 14,93',
#    '22/04 UBER* TRIP 19,94',
#    '22/04 RAIA112 60,89',
#    '22/04 PANVEL FARMACIAS 12,13',
#    '22/04 Uber *UBER *TRIP 14,99',
#    '21/04 B S A WARES LTDA 1/3 72,68',
#    '21/04 MP *PICOLEDOCUNHA 10,00',
#    '21/04 JOALDO A DOS ANJOS 59,00',
#    '21/04 LOJA DO TREM SOUVENIER 44,00',
#    '21/04 CASA BANANINA 75,00',
#    '21/04 ARMAZEM DO ARTESANATO 48,00'],
#   ['20/04 MUSEU OSCAR NIEMEYER 1/2 60,00',
#    '20/04 PRESTINARIA 37,00',
#    '20/04 Uber *UBER *TRIP 39,94',
#    '20/04 VALE DA MUSICA 30,00',
#    '19/04 DIGIPARE 50,00',
#    '19/04 HEBRAICA PARKING 35,00',
#    '18/04 RAIA3808 1/2 89,43',
#    '15/04 BUFFON 43 261,19',
#    '14/04 Vindi *Figmigcentrode 109,90',
#    '13/04 PARC=103MIOSE 1/3 96,58',
#    '13/04PARC=103LOOK BACANA',
#    'MODAS 1/372,68',
#    '13/04 FEIRAO DE CALCADO 1/2 85,00',
#    '13/04 PG *TON OSNI 1/2 105,00',
#    '13/04 PAG*LiseteCorreia 1/3 46,68',
#    '13/04 PAG*MicheleTricot 1/10 30,98',
#    '13/04 PAG*LiseteCorreia 1/2 115,00',
#    '13/04 BUFFON 36 21,97',
#    '09/04 Uber *UBER *TRIP 14,95',
#    '08/04 MOCELLIN COMERCIO DE B 78,98',
#    '08/04 RAIA4366 39,38',
#    '08/04 PAG*ArmazemPontual 13,00'],
#   ['08/04 PETIT CONVENIENCIA 7,50',
#    '08/04 PAG*Adulla 11,48',
#    '07/04 ARMAZEM NATIVOS 10,00',
#    '04/04 Uber *UBER *TRIP 14,05',
#    '03/04 PAG*MercadoMoinhos 20,39',
#    '02/04 MP *MELIMAIS 17,99',
#    '01/04 APOIASE*APOIAse Vario 40,00',
#    '30/03 ALLPARK EMPREENDIMENTOS 12,75',
#    '30/03 PAG*Studiosisters 59,00',
#    '28/03PARC=110',
#    'HTM*BOCAROSACOMP 1/10116,22',
#    '28/03 BELSHOP PERFUMARIA E C 103,00',
#    '28/03 PAG*FigmigCentroDe 44,00',
#    '28/03 ARMAZEM 43. 24OUT 21,87',
#    '09/03 CEA PAC 300 ECPC 2/2 70,60',
#    '27/02 CA Modas Ltda. CEA-664424 2/3 497,32',
#    '30/11 ZEREZES DESIGN 5/8 123,75',
#    '24/11 Azul *FM12VAOliveir 6/6 69,80',
#    '12/09JOULI SAUDE EM ESTETICA L',
#    '8/10100,00',
#    '06/09 AMAZON BR 8/10 149,15',
#    '29/08JOULI SAUDE EM ESTETICA L',
#    '8/12170,83'],
#   ['11/07 AMAZON MARKETPLACE 10/10 68,14',
#    '01/07JOULI SAUDE EM ESTETICA L',
#    '10/12345,83',
#    '.Total para RAFAELA',
#    'KOEFENDER. ..R$',
#    '4.360,80',
#    '. Total da Fatura em Real . ..R$',
#    '5.141,52']]]

# %%
parsed_data = []

# Loop through each main section
for section in consolidated_info:
    for card_section in section:
        # Split the section into lines
        lines = card_section
        card_info = {
            'Card Details': [],
            'Transactions': [],
            'Total': None
        }
        for line in lines:
            if line.startswith('XXXX.XXXX.XXXX'):
                # This line contains cardholder details
                card_info['Card Details'] = line.split('XXXX')
            elif line.startswith('.Total para'):
                # This line contains the total
                card_info['Total'] = line.split('.Total para ')[1]
            else:
                # This line contains a transaction
                card_info['Transactions'].append(line)
        parsed_data.append(card_info)

# Printing parsed data
for card in parsed_data:
    print(f"Card Details: {card['Card Details']}")
    print("Transactions:")
    for transaction in card['Transactions']:
        print(f"  - {transaction}")
    print(f"Total: {card['Total']}")
    print("")
# Out:
# Card Details: ['', '.', '.', '.9787', '.', '.', '.9787']
# Transactions:
#   - Aplicativo Bradesco Cartões
#   - Data: 27/05/2024 - 21:31
#   - Situação do Extrato: FECHADO
#   - JOAO PEDRO CHAGAS - VISA INFINITE
#   - Data HistóricoMoeda de
#   - origemUS$Cotação
#   - US$R$
#   - CHAGAS. .. R$ 0,00
#   - JOAO PEDRO CHAGAS - VISA INFINITE
#   - Data HistóricoMoeda de
#   - origemUS$Cotação
#   - US$R$
#   - 25/12 POSTOS BAUER IIII 200,38
#   - 24/12 Sem Par*Sem Parar * 97,00
#   - 24/12 FARMACIA XAXIM 30,88
#   - 23/12 POSTO Z4 222,48
#   - 23/12 MIRANTES 36,00
#   - 21/12 EBN *SPOTIFY 34,90
#   - 20/12 FERRAMENTAS GERAIS 17,27
#   - 18/12KALUNGA IGUATEMI PORTO
#   - 1/359,34
#   - 18/12 MULTIFESTA 9,98
#   - 17/12 VELEIROS DO SUL 25,00
# Total: JOAO PEDRO
#
# Card Details: []
# Transactions:
#   - 17/12 99APP *99App 25,95
#   - 17/12 PG *LEROY MERLIN LEROY 69,90
#   - 16/12 N Y ARTIGO 1/4 62,75
#   - 16/12 PUC CAMPUS FACULDADE 10,00
#   - 16/12 99APP *99App 27,10
#   - 15/12 EC*INSIDERSTORE 1/3 154,67
#   - 15/12 MP *UNICOMPECASPA 18,00
#   - 15/12 CASA ARCO 70,00
#   - 15/12 PAG*Barbershop 30,00
#   - 14/12 PORTO SEGURO CIA SEG G 185,34
#   - 14/12 Uber *UBER *TRIP 20,93
#   - 14/12 99APP *99App 17,90
#   - 11/12 PAGTO. POR DEB EM C/C -8.660,94
#   - 10/12 SALDO ANTERIOR 8.660,94
#   - 09/12 LE BATEAU IVRE 375,65
#   - 09/12 PAG*CasaMaria 139,80
#   - 05/12 SOMPO *Parcela*3-3 92,64
#   - 04/12 99* POP 04Dez 09h58min 8,73
#   - 04/12 99* POP 04Dez 08h57min 8,60
#   - 03/12 99* POP 03Dez 00h45min 32,16
#   - 03/12 Uber *UBER *TRIP 11,70
# Total: None
#
# Card Details: ['', '.', '.', '.481102/12 UBER* TRIP 5,00']
# Transactions:
#   - 02/12 FARM POP UP PRAIA DE B 149,00
#   - 02/12 PONTE CAPITAL LTDA EPP 111,10
#   - 02/12 CASA DO VALE 137,68
#   - 02/12 HAVAIANAS 69,99
#   - 01/12 FUI GOSTEI AGENCIA DE 1.065,67
#   - 01/12 FAREJANDOST 1/2 174,00
#   - 01/12 MP *CASARIOATELIE 72,00
#   - 01/12 ZAFFARI F. MACHAD 75,70
#   - 30/11 AmazonPrimeBR 14,90
#   - 30/10 AMAZON MARKETPLACE 2/4 62,22
#   - 08/10 PG *SPIRITO SANTO 3/6 183,17
#   - 06/09 CNS IG PORTO ALEGRE 4/6 114,83
#   - CHAGAS. ..R$
#   - 4.330,31
#   - RAFAELA KOEFENDER - VISA INFINITE
#   - Data HistóricoMoeda de
#   - origemUS$Cotação
#   - US$R$
#   - 23/12 HNA*OBOTICARIO 1/4 78,19
#   - 23/12 SHOPPING DO REAL 54,85
#   - 22/12 AREATECTECNO*Digipare 5,00
#   - 22/12 PAG*FigmigCentroDe 132,50
#   - 21/12 UBER* TRIP 30,43
# Total: JOAO PEDRO
#
# Card Details: []
# Transactions:
#   - 21/12 COTTON ON DO FILIAL 00 1/2 89,95
#   - 21/12DECATHLON PRAIA DE BEL
#   - 1/274,98
#   - 21/12LOCCITANE PRAIA DE BEL
#   - 1/468,65
#   - 21/12 LOESCH E SCHUCK ADMI 40,00
#   - 20/12 Uber *UBER *TRIP 14,93
#   - 19/12 CASA DO PAPEL 5,78
#   - 18/12 STUDIO FLOE 99,00
#   - 18/12 K2 COMERCIO E INDUSTRI 1/4 67,50
#   - 16/12 J L C ARTIGOS DO VESTU 44,99
#   - 16/12 LOJAS AMERICANAS 42 149,39
#   - 16/12 Uber *UBER *TRIP 20,80
#   - 16/12 BAR ODESSA 39,35
#   - 16/12 TUYO 99,00
#   - 15/12 EC*INSIDERSTORE 1/3 264,68
#   - 14/12 SABOR DE LUNA 6,60
#   - 13/12 PAG*MercadoMoinhos 26,74
#   - 12/12 CEA PAB 310 ECPC 1/3 150,99
#   - 12/12 RAIA 210 131,71
#   - 12/12 LOJAS AMERICANAS 154 36,47
#   - 11/12 PAG*ICASEIPRESENTES 331,57
# Total: None
#
# Card Details: []
# Transactions:
#   - 11/12 NETFLIX.COM 52,80
#   - 11/12 PUBLIC MARKET 21,60
#   - 09/12 PAG*MaxmixComercial 149,96
#   - 08/12 POSTO SHOPPING 246,67
#   - 06/12 AREATECTECNO*Digipare 50,00
#   - 05/12 MERCADO MOINHOS 9,45
#   - 05/12 PANVEL FARMACIAS 25,41
#   - 04/12 369 ARMAZEM CAFE 16,34
#   - 04/12 MP *MELIMAIS 17,99
#   - 03/12 RAIA3286 1/3 65,40
#   - 01/12 APOIASE*APOIAse apadr 15,00
#   - 30/11 ZEREZES DESIGN 1/8 123,75
#   - 30/11 UBER* TRIP 14,91
#   - 30/11 UBER* TRIP 34,40
#   - 30/11 RAIA1504 111,81
#   - 30/11 TAISHI SUSHI 65,89
#   - 30/11 PG *TON CRUA SLOW BE 256,00
#   - 29/11 BACIO LJ 0092 RUA P CH 17,95
#   - 24/11 Azul *FM12VAOliveir 2/6 69,80
#   - 23/11 PAG*Panvelfilial407 2/2 34,78
#   - 21/11 FARMACIA SAO JOAO 2/2 65,68
#   - 01/11 PAG*DanielleLouiseAce 2/2 157,50
# Total: None
#
# Card Details: []
# Transactions:
#   - 01/11 CHEVERE 2/2 79,95
#   - 30/10 PANVEL FARMACIAS 2/2 87,89
#   - 25/10 simple *SimpleOrganic 3/4 62,15
#   - 10/10 PAG*PetzCarlosBerta 3/4 88,48
#   - 12/09JOULI SAUDE EM ESTETICA L
#   - 4/10100,00
#   - 06/09 AMAZON BR 4/10 149,15
#   - 06/09 RENNER 4/4 61,45
#   - 29/08JOULI SAUDE EM ESTETICA L
#   - 4/12170,83
#   - 18/08 AMAZON MARKETPLACE 5/7 52,97
#   - 01/08 RENNER 5/5 95,98
#   - 22/07 Vindi *CasaBoaVistaTe 6/6 54,16
#   - 11/07 AMAZON MARKETPLACE 6/10 68,14
#   - 01/07JOULI SAUDE EM ESTETICA L
#   - 6/12345,83
#   - 31/03JOULI SAUDE EM ESTETICA L
#   - 9/1095,00
#   - 23/02 PARC=112CONQUER 11/12 158,75
#   - 25/01 EBW*CANVA 12/12 24,15
#   - KOEFENDER. ..R$
#   - 5.382,02
#   - . Total da Fatura em Real . ..R$
#   - 9.712,33
# Total: RAFAELA
#
# Card Details: []
# Transactions:
# Total: None
#
# Card Details: ['', '.', '.', '.9787', '.', '.', '.9787']
# Transactions:
#   - Aplicativo Bradesco Cartões
#   - Data: 27/05/2024 - 21:31
#   - Situação do Extrato: FECHADO
#   - JOAO PEDRO CHAGAS - VISA INFINITE
#   - Data HistóricoMoeda de
#   - origemUS$Cotação
#   - US$R$
#   - CHAGAS. .. R$ 0,00
#   - JOAO PEDRO CHAGAS - VISA INFINITE
#   - Data HistóricoMoeda de
#   - origemUS$Cotação
#   - US$R$
#   - 28/01 PAG*RejaneFerreiraDa 114,00
#   - 28/01 PAG*LancheriaAmigosDa 49,10
#   - 27/01 NOSTRO MOLINO RESTAURA 218,57
#   - 27/01 CNO GASTRONOMIA LTDA 167,91
#   - 26/01 DECATHLON PRAIA DE BEL 19,98
#   - 24/01 FARMACIA MARCELA 30,50
#   - 24/01 Sem Par*Sem Parar * 23,20
#   - 23/01 99APP *99App 10,00
#   - 23/01 99* POP 23Jan 09h56min 9,76
#   - 21/01 EBN *SPOTIFY 34,90
# Total: JOAO PEDRO
#
# Card Details: ['', '.', '.', '.481120/01 PET LOVE*Order10054397 146,80']
# Transactions:
#   - 10/01 SALDO ANTERIOR 9.712,33
#   - 10/01 PAGTO. POR DEB EM C/C -9.712,33
#   - 31/12 AmazonPrimeBR 14,90
#   - 18/12KALUNGA IGUATEMI PORTO
#   - 2/359,33
#   - 16/12 N Y ARTIGO 2/4 62,72
#   - 15/12 EC*INSIDERSTORE 2/3 154,67
#   - 01/12 FAREJANDOST 2/2 174,00
#   - 30/10 AMAZON MARKETPLACE 3/4 62,22
#   - 08/10 PG *SPIRITO SANTO 4/6 183,17
#   - 06/09 CNS IG PORTO ALEGRE 5/6 114,83
#   - CHAGAS. ..R$
#   - 1.650,56
#   - RAFAELA KOEFENDER - VISA INFINITE
#   - Data HistóricoMoeda de
#   - origemUS$Cotação
#   - US$R$
#   - 25/01 DINARTE RESTAURANTE L 88,00
#   - 25/01 CASA DO PAPEL 5,38
#   - 22/01 AREATECTECNO*Digipare 50,00
#   - 22/01 AREATECTECNO*Digipare 50,00
#   - 20/01 3434RAIA 24,18
#   - 20/01 ABASTEC*abastece ai 214,57
# Total: JOAO PEDRO
#
# Card Details: []
# Transactions:
#   - 20/01 PAG*SabineMarianeSaue 28,00
#   - 15/01 HOTEL MONTE CARLO 344,00
#   - 15/01 POSTO PRIMAR 136,01
#   - 15/01 EMPORIO PROSPERATO 49,00
#   - 14/01 BOTECO BEER 127,00
#   - 11/01 NETFLIX.COM 52,80
#   - 03/01 MP *MELIMAIS 17,99
#   - 01/01 APOIASE*APOIAse apadr 15,00
#   - 23/12 HNA*OBOTICARIO 2/4 78,17
#   - 21/12 COTTON ON DO FILIAL 00 2/2 89,95
#   - 21/12DECATHLON PRAIA DE BEL
#   - 2/274,98
#   - 21/12 LOCCITANE PRAIA DE BEL 2/4 68,65
#   - 18/12 K2 COMERCIO E INDUSTRI 2/4 67,50
#   - 15/12 EC*INSIDERSTORE 2/3 264,66
#   - 12/12 CEA PAB 310 ECPC 2/3 150,98
#   - 03/12 RAIA3286 2/3 65,39
#   - 30/11 ZEREZES DESIGN 2/8 123,75
#   - 24/11 Azul *FM12VAOliveir 3/6 69,80
#   - 25/10 simple *SimpleOrganic 4/4 62,15
#   - 10/10 PAG*PetzCarlosBerta 4/4 88,48
#   - 12/09JOULI SAUDE EM ESTETICA L
#   - 5/10100,00
# Total: None
#
# Card Details: []
# Transactions:
#   - 06/09 AMAZON BR 5/10 149,15
#   - 29/08JOULI SAUDE EM ESTETICA L
#   - 5/12170,83
#   - 18/08 AMAZON MARKETPLACE 6/7 52,97
#   - 11/07 AMAZON MARKETPLACE 7/10 68,14
#   - 01/07JOULI SAUDE EM ESTETICA L
#   - 7/12345,83
#   - 31/03JOULI SAUDE EM ESTETICA L
#   - 10/1095,00
#   - 23/02 PARC=112CONQUER 12/12 158,75
#   - KOEFENDER. ..R$
#   - 3.547,06
#   - . Total da Fatura em Real . ..R$
#   - 5.197,62
# Total: RAFAELA
#
# Card Details: ['', '.', '.', '.9787', '.', '.', '.9787']
# Transactions:
#   - Aplicativo Bradesco Cartões
#   - Data: 27/05/2024 - 21:31
#   - Situação do Extrato: FECHADO
#   - JOAO PEDRO CHAGAS - VISA INFINITE
#   - Data HistóricoMoeda de
#   - origemUS$Cotação
#   - US$R$
#   - CHAGAS. .. R$ 0,00
#   - JOAO PEDRO CHAGAS - VISA INFINITE
#   - Data HistóricoMoeda de
#   - origemUS$Cotação
#   - US$R$
#   - 23/02 Sem Par*Sem Parar * 114,60
#   - 18/02 AMAZON MARKETPLACE 36,90
#   - 17/02 PAG*Barbershop 30,00
#   - 17/02 AMAZON MARKETPLACE 81,98
#   - 15/02PORTO SEGURO CIA SEG G
#   - 1/10241,55
#   - 15/02 PAG*Safe 15,00
#   - 14/02 PAGTO. POR DEB EM C/C -5.197,62
#   - 14/02 DECATHLON PRAIA DE BEL 9,98
#   - 13/02 RAIA DROGASIL S A 1/3 26,64
#   - 11/02 SUPER LOJA 15,98
# Total: JOAO PEDRO
#
# Card Details: []
# Transactions:
#   - 11/02 KARINE DE SOUZA BITTEN 84,00
#   - 10/02 SALDO ANTERIOR 5.197,62
#   - 10/02 NADIA SIMONE SANTOS DE 96,00
#   - 09/02 ABASTEC*abastece ai 210,32
#   - 07/02 BOURBON IPIRANGA 1/3 156,22
#   - 06/02 PAG*OdecioEtter 20,00
#   - 05/02 MAKRO CENTRAL DE AVIAM 14,39
#   - 05/02 99* 6,30
#   - 05/02 Gympass GympassBr 269,90
#   - 04/02MOO VEGGIE FOOD
#   - RESTAURAN123,70
#   - 04/02 CIA DO ESCONDIDINHO 152,00
#   - 04/02 Gympass GympassBr 129,90
#   - 03/02 PAG*RejaneFerreiraDa 20,00
#   - 03/02 PAG*PointMixChurros 20,00
#   - 02/02 LOJA E BAZAR TODO DIA 1/3 37,97
#   - 02/02 JEFERSON BITTENCOURT C 12,00
#   - 02/02 COMERCIAL UNIAO EIRELI 69,88
#   - 02/02 SUPERBOM SUPERMERCADO 107,88
#   - 31/01 AmazonPrimeBR 14,90
#   - 29/01 PAG*LucasBarreiro 204,00
#   - 18/12KALUNGA IGUATEMI PORTO
#   - 3/359,33
# Total: None
#
# Card Details: ['', '.', '.', '.481116/12 N Y ARTIGO 3/4 62,72']
# Transactions:
#   - 15/12 EC*INSIDERSTORE 3/3 154,67
#   - 30/10 AMAZON MARKETPLACE 4/4 62,22
#   - 08/10 PG *SPIRITO SANTO 5/6 183,17
#   - 06/09 CNS IG PORTO ALEGRE 6/6 114,83
#   - CHAGAS. ..R$
#   - 2.958,93
#   - RAFAELA KOEFENDER - VISA INFINITE
#   - Data HistóricoMoeda de
#   - origemUS$Cotação
#   - US$R$
#   - 27/02 CA Modas Ltda. CEA-664424 1/3 497,33
#   - 27/02 BUFFON 43 4,98
#   - 27/02 PANVEL FARMACIAS 79,06
#   - 27/02 BUFFON 43 12,45
#   - 23/02 CONQUER 158,75
#   - 22/02 BACIO LJ 0092 RUA P CH 46,90
#   - 22/02 MERCADO MORARI 28,90
#   - 22/02 AMAZON MARKETPLACE 99,99
#   - 21/02 MERCADO MORARI 7,00
#   - 19/02 SHOULDER E-COMMERCE 459,00
#   - 19/02 PG *FELICITOUS LUCAS40 150,00
#   - 17/02 HOSPITAL MAE DE DEUS G 42,00
# Total: JOAO PEDRO
#
# Card Details: []
# Transactions:
#   - 16/02 DIGIPARE 50,00
#   - 11/02 NETFLIX ENTRETENIMENTO 52,80
#   - 10/02 PANVEL FARMACIAS 749 36,51
#   - 09/02 PAG*FigmigCentroDe 40,00
#   - 08/02 PDV*SANTINO.ARTISAN 16,00
#   - 06/02 HNA*OBOTICARIO 1/2 86,40
#   - 06/02 AREATECTECNO*Digipare 50,00
#   - 06/02 IGUATEMI 28,00
#   - 06/02 IGUATEMI 39,50
#   - 06/02 PAG*MercadoMoinhos 29,50
#   - 06/02 PAG*PortoAlegreSthShP 44,90
#   - 02/02 MP *MELIMAIS 17,99
#   - 01/02 DROGARIA ONL*Drog 1/2 117,57
#   - 01/02 APOIASE*APOIAse apadr 15,00
#   - 01/02 PAG*FigmigCentroDe 84,00
#   - 01/02 LS FARMACIAS 27,90
#   - 31/01 DROGARIA ONL*Drog 1/2 65,45
#   - 31/01 MERCADO MOINHOS 40,50
#   - 31/01 ZAFFARI C. COLOMB 10,90
#   - 31/01 abastec*abastece ai 245,35
#   - 30/01 SIMPLE POA 1/2 102,45
# Total: None
#
# Card Details: []
# Transactions:
#   - 29/01 PANVEL FARMACIAS 9,99
#   - 29/01 PAG*MercadoMoinhos 8,55
#   - 23/12 HNA*OBOTICARIO 3/4 78,17
#   - 21/12LOCCITANE PRAIA DE BEL
#   - 3/468,65
#   - 18/12 K2 COMERCIO E INDUSTRI 3/4 67,50
#   - 15/12 EC*INSIDERSTORE 3/3 264,66
#   - 12/12 CEA PAB 310 ECPC 3/3 150,98
#   - 03/12 RAIA3286 3/3 65,39
#   - 30/11 ZEREZES DESIGN 3/8 123,75
#   - 24/11 Azul *FM12VAOliveir 4/6 69,80
#   - 12/09JOULI SAUDE EM ESTETICA L
#   - 6/10100,00
#   - 06/09 AMAZON BR 6/10 149,15
#   - 29/08JOULI SAUDE EM ESTETICA L
#   - 6/12170,83
#   - 18/08 AMAZON MARKETPLACE 7/7 52,97
#   - 11/07 AMAZON MARKETPLACE 8/10 68,14
#   - 01/07JOULI SAUDE EM ESTETICA L
#   - 8/12345,83
#   - KOEFENDER. ..R$
#   - 4.581,44
#   - . Total da Fatura em Real . ..R$
#   - 7.540,37
# Total: RAFAELA
#
# Card Details: ['', '.', '.', '.9787', '.', '.', '.9787']
# Transactions:
#   - Aplicativo Bradesco Cartões
#   - Data: 27/05/2024 - 21:31
#   - Situação do Extrato: FECHADO
#   - JOAO PEDRO CHAGAS - VISA INFINITE
#   - Data HistóricoMoeda de
#   - origemUS$Cotação
#   - US$R$
#   - CHAGAS. .. R$ 0,00
#   - JOAO PEDRO CHAGAS - VISA INFINITE
#   - Data HistóricoMoeda de
#   - origemUS$Cotação
#   - US$R$
#   - 23/03 Sem Par*Sem Parar * 17,45
#   - 23/03 PAG*Barbershop 30,00
#   - 23/03 VENEZA PADARIA 12,50
#   - 23/03 LH FRANCO 10,00
#   - 23/03 MERCADO OLIMPICO 15,00
#   - 11/03 PAGTO. POR DEB EM C/C -7.540,37
#   - 10/03 SALDO ANTERIOR 7.540,37
#   - 15/02PORTO SEGURO CIA SEG G
#   - 2/10241,53
#   - 13/02 RAIA DROGASIL S A 2/3 26,63
#   - 07/02 BOURBON IPIRANGA 2/3 156,22
# Total: JOAO PEDRO
#
# Card Details: ['', '.', '.', '.481102/02 LOJA E BAZAR TODO DIA 2/3 37,96']
# Transactions:
#   - 16/12 N Y ARTIGO 4/4 62,72
#   - 08/10 PG *SPIRITO SANTO 6/6 183,17
#   - CHAGAS. ..R$
#   - 793,18
#   - RAFAELA KOEFENDER - VISA INFINITE
#   - Data HistóricoMoeda de
#   - origemUS$Cotação
#   - US$R$
#   - 26/03 Uber *UBER *TRIP 21,36
#   - 26/03 Uber *UBER *TRIP 8,91
#   - 26/03 ARMAZEM 43. 24OUT 24,50
#   - 25/03 ARMAZEM 43. 24OUT 27,77
#   - 22/03 DIGIPARE 50,00
#   - 20/03 369 ARMAZEM CAFE 12,75
#   - 19/03 PAG*PanvelFilial9 59,07
#   - 16/03 REK PARKING EMPREEND E 25,00
#   - 16/03 POSTO PERIMETRAL 186,59
#   - 14/03 pgz*ISAINSTIT 169,00
#   - 14/03 Vindi *Figmigcentrode 109,90
#   - 12/03 APOIASE*APOIAse proje 25,00
#   - 11/03 DIGIPARE 50,00
#   - 09/03 CEA PAC 300 ECPC 1/2 70,61
# Total: JOAO PEDRO
#
# Card Details: []
# Transactions:
#   - 08/03 UBER* TRIP 8,94
#   - 08/03 DERMO MOINHOS 37,20
#   - 08/03 Uber *UBER *TRIP 9,36
#   - 08/03 INCOMUM 10,00
#   - 07/03 369 ARMAZEM CAFE 3,50
#   - 06/03 210RAIA 96,93
#   - 06/03 PANVEL FARMACIAS 99,48
#   - 06/03 ARMAZEM 43. 24OUT 14,00
#   - 05/03 PG *DROGARAIA DROGARIA 69,01
#   - 03/03 MP *MELIMAIS 17,99
#   - 01/03 APOIASE*APOIAse apadr 15,00
#   - 28/02 RAIA DROGASIL SA 55,90
#   - 06/02 HNA*OBOTICARIO 2/2 86,40
#   - 01/02 DROGARIA ONL*Drog 2/2 117,56
#   - 31/01 DROGARIA ONL*Drog 2/2 65,44
#   - 30/01 SIMPLE POA 2/2 102,45
#   - 23/12 HNA*OBOTICARIO 4/4 78,17
#   - 21/12LOCCITANE PRAIA DE BEL
#   - 4/468,65
#   - 18/12 K2 COMERCIO E INDUSTRI 4/4 67,50
#   - 30/11 ZEREZES DESIGN 4/8 123,75
#   - 24/11 Azul *FM12VAOliveir 5/6 69,80
# Total: None
#
# Card Details: []
# Transactions:
#   - 12/09JOULI SAUDE EM ESTETICA L
#   - 7/10100,00
#   - 06/09 AMAZON BR 7/10 149,15
#   - 29/08JOULI SAUDE EM ESTETICA L
#   - 7/12170,83
#   - 11/07 AMAZON MARKETPLACE 9/10 68,14
#   - 01/07JOULI SAUDE EM ESTETICA L
#   - 9/12345,83
#   - KOEFENDER. ..R$
#   - 2.891,44
#   - . Total da Fatura em Real . ..R$
#   - 3.684,62
# Total: RAFAELA
#
# Card Details: ['', '.', '.', '.9787', '.', '.', '.9787']
# Transactions:
#   - Aplicativo Bradesco Cartões
#   - Data: 27/05/2024 - 21:31
#   - Situação do Extrato: FECHADO
#   - JOAO PEDRO CHAGAS - VISA INFINITE
#   - Data HistóricoMoeda de
#   - origemUS$Cotação
#   - US$R$
#   - CHAGAS. .. R$ 0,00
#   - JOAO PEDRO CHAGAS - VISA INFINITE
#   - Data HistóricoMoeda de
#   - origemUS$Cotação
#   - US$R$
#   - 28/04IFD*OUTBACK STEAKHOUSE
#   - RE250,39
#   - 23/04 Sem Par*Sem Parar * 67,99
#   - 10/04 SALDO ANTERIOR 3.684,62
#   - 10/04 PAGTO. POR DEB EM C/C -3.684,62
#   - 15/02 PORTO SEGURO CIA SEG G 3/10 241,53
#   - 13/02 RAIA DROGASIL S A 3/3 26,63
#   - 07/02 BOURBON IPIRANGA 3/3 156,22
#   - 02/02 LOJA E BAZAR TODO DIA 3/3 37,96
#   - CHAGAS. ..R$
#   - 780,72
# Total: JOAO PEDRO
#
# Card Details: ['', '.', '.', '.4811 RAFAELA KOEFENDER - VISA INFINITE']
# Transactions:
#   - Data HistóricoMoeda de
#   - origemUS$Cotação
#   - US$R$
#   - 27/04 PAG*FigmigCentroDe 47,50
#   - 27/04 PAG*CmCentroDeBeleza 59,00
#   - 23/04 PAG*GamalFouadEl 1/5 105,40
#   - 23/04 UBER* TRIP 11,97
#   - 23/04 PANVEL FARMACIAS 87,89
#   - 23/04 Uber *UBER *TRIP 13,90
#   - 23/04 K & M ARTESANATOS 34,00
#   - 22/04 RESTAURANTE AROMA MINE 63,25
#   - 22/04 UBER* TRIP 14,93
#   - 22/04 UBER* TRIP 19,94
#   - 22/04 RAIA112 60,89
#   - 22/04 PANVEL FARMACIAS 12,13
#   - 22/04 Uber *UBER *TRIP 14,99
#   - 21/04 B S A WARES LTDA 1/3 72,68
#   - 21/04 MP *PICOLEDOCUNHA 10,00
#   - 21/04 JOALDO A DOS ANJOS 59,00
#   - 21/04 LOJA DO TREM SOUVENIER 44,00
#   - 21/04 CASA BANANINA 75,00
#   - 21/04 ARMAZEM DO ARTESANATO 48,00
# Total: None
#
# Card Details: []
# Transactions:
#   - 20/04 MUSEU OSCAR NIEMEYER 1/2 60,00
#   - 20/04 PRESTINARIA 37,00
#   - 20/04 Uber *UBER *TRIP 39,94
#   - 20/04 VALE DA MUSICA 30,00
#   - 19/04 DIGIPARE 50,00
#   - 19/04 HEBRAICA PARKING 35,00
#   - 18/04 RAIA3808 1/2 89,43
#   - 15/04 BUFFON 43 261,19
#   - 14/04 Vindi *Figmigcentrode 109,90
#   - 13/04 PARC=103MIOSE 1/3 96,58
#   - 13/04PARC=103LOOK BACANA
#   - MODAS 1/372,68
#   - 13/04 FEIRAO DE CALCADO 1/2 85,00
#   - 13/04 PG *TON OSNI 1/2 105,00
#   - 13/04 PAG*LiseteCorreia 1/3 46,68
#   - 13/04 PAG*MicheleTricot 1/10 30,98
#   - 13/04 PAG*LiseteCorreia 1/2 115,00
#   - 13/04 BUFFON 36 21,97
#   - 09/04 Uber *UBER *TRIP 14,95
#   - 08/04 MOCELLIN COMERCIO DE B 78,98
#   - 08/04 RAIA4366 39,38
#   - 08/04 PAG*ArmazemPontual 13,00
# Total: None
#
# Card Details: []
# Transactions:
#   - 08/04 PETIT CONVENIENCIA 7,50
#   - 08/04 PAG*Adulla 11,48
#   - 07/04 ARMAZEM NATIVOS 10,00
#   - 04/04 Uber *UBER *TRIP 14,05
#   - 03/04 PAG*MercadoMoinhos 20,39
#   - 02/04 MP *MELIMAIS 17,99
#   - 01/04 APOIASE*APOIAse Vario 40,00
#   - 30/03 ALLPARK EMPREENDIMENTOS 12,75
#   - 30/03 PAG*Studiosisters 59,00
#   - 28/03PARC=110
#   - HTM*BOCAROSACOMP 1/10116,22
#   - 28/03 BELSHOP PERFUMARIA E C 103,00
#   - 28/03 PAG*FigmigCentroDe 44,00
#   - 28/03 ARMAZEM 43. 24OUT 21,87
#   - 09/03 CEA PAC 300 ECPC 2/2 70,60
#   - 27/02 CA Modas Ltda. CEA-664424 2/3 497,32
#   - 30/11 ZEREZES DESIGN 5/8 123,75
#   - 24/11 Azul *FM12VAOliveir 6/6 69,80
#   - 12/09JOULI SAUDE EM ESTETICA L
#   - 8/10100,00
#   - 06/09 AMAZON BR 8/10 149,15
#   - 29/08JOULI SAUDE EM ESTETICA L
#   - 8/12170,83
# Total: None
#
# Card Details: []
# Transactions:
#   - 11/07 AMAZON MARKETPLACE 10/10 68,14
#   - 01/07JOULI SAUDE EM ESTETICA L
#   - 10/12345,83
#   - KOEFENDER. ..R$
#   - 4.360,80
#   - . Total da Fatura em Real . ..R$
#   - 5.141,52
# Total: RAFAELA

# %%
tuples = []
for c in charges:
    c_splitted = c.split()
    data = c_splitted[0]
    descricao = ""
    valor = 0
    transacao = ""
    if c_splitted[-1] == 'C':
        transacao = "receita"
        valor = c_splitted[-2]
        descricao = ''.join(c_splitted[1:-3])
        tuples.append((data,descricao,valor,transacao))
    elif c_splitted[-1] == 'D':
        transacao = "despesa"
        valor = c_splitted[-2]
        descricao = ''.join(c_splitted[1:-3])
        tuples.append((data,descricao,valor,transacao))

df = pd.DataFrame(tuples, columns =['data', 'descricao', 'valor','transacao'])
df['metodo'] = 'pix ou transferencia'
df['banco'] = 'c6'
df['parcela'] = 1
df['qt_parcelas'] = 1

# %%
df['data'] = pd.to_datetime(df['data'],format='%d/%m/%Y')

# %%
df['month'] = df['data'].dt.month

# %%
grouped = df.groupby('month')

# %%
dfs = {month: grouped.get_group(month) for month in grouped.groups}

# %%
for i in dfs:
    dfs[i].to_csv(f'/home/jpchagas/Downloads/C6_{i}.csv')

# %%
data = ""
descricao = ""
valor = 0
transacao = ""
month_number = ""
year = ""
tuples = []
for c in charges:
    match_data = re.match('\+\+\s*MOVIMENTOS\s+(\w+)\/(\d{4})',c)
    match_transaction = re.match('^(\d*)\s+(\D+)\s+\d+\s+(\d+\,\d+)(\-*)', c)
    if match_data:
        print
        month_number = get_month_number_abbr(match_data.group(1))
        year = match_data.group(2)
    elif match_transaction:
        if match_transaction.group(1) != '':
            data = f'{match_transaction.group(1)}/{month_number}/{year}'
        descricao = match_transaction.group(2)
        valor = match_transaction.group(3)
        if match_transaction.group(4) == '':
            transacao = "receita"
        else:
            transacao = "despesa"
        tuples.append((data,descricao,float(convert_brazil_to_us_currency(valor)),transacao))

# %%
tuples

# %%
df = pd.DataFrame(tuples, columns =['data', 'descricao', 'valor','transacao'])
df['metodo'] = 'pix ou transferencia'
df['banco'] = 'banrisul'
df['parcela'] = 1
df['qt_parcelas'] = 1

# %%
charges_tuples=[]
for c in charges:
    c_splitted = c.split()
    data = c_splitted[0]
    description = ""
    for i in range(2,len(c_splitted)-2):
            description += c_splitted[i]
    value = c_splitted[len(c_splitted)-2]
    transaction_type = c_splitted[len(c_splitted)-1]
    charges_tuples.append((data,description,float(convert_brazil_to_us_currency(value)),transaction_type))

# %%
charges_tuples

# %%
charges_tuples=[]
for c in charges:
    c_splitted = c.split()
    data = None
    if re.match(date_pattern_year, c_splitted[0]):
        print("match")
        data = c_splitted[0]
    else:
        print("no match")
        current_year = datetime.now().year
        data = c_splitted[0]+"/"+str(current_year)
    amount = c_splitted[len(c_splitted)-1]
    description = ""
    fraction = ""
    if re.match(fraction_pattern, c_splitted[len(c_splitted)-2]):
        fraction = c_splitted[len(c_splitted)-2]
        for i in range(1,len(c_splitted)-2):
            description += c_splitted[i]
        #Concatenar outros elementos
        charges_tuples.append((data,description,fraction,float(convert_brazil_to_us_currency(amount))))
    else:
        for i in range(1,len(c_splitted)-1):
            description += c_splitted[i]
        #Concatenar outros elements
        charges_tuples.append((data,description,fraction,float(convert_brazil_to_us_currency(amount))))
df = pd.DataFrame(charges_tuples, columns =['data', 'descricao', 'parcela','valor'])
indexDescription1 = df[df['description'] == 'PAGTO.PORDEBEMC/C'].index
indexDescription2 = df[df['description'] == 'SALDOANTERIOR'].index
df.drop(indexDescription1 , inplace=True)
df.drop(indexDescription2 , inplace=True)
qt_parcelas = []
parcela = []
for i in df['parcela']:
    p,qt_p = i.split("/")
    parcela.append(p)
    qt_parcelas.append(qt_p)
df['parcela'] = parcela
df['qt_parcelas'] = qt_parcelas
df = df.drop(columns=['Parcela'])
df['transacao'] = 'despesa'
df['metodo'] = 'cc'
df['banco'] = 'c6'

# %%
charges_tuples
